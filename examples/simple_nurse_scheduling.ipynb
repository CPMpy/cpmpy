# %% [markdown]
# # Nurse scheduling in CPMpy

# %%
from cpmpy import *

def simple_nurse_rostering(num_nurses, shifts_per_day, num_days):

    # Define the variables
    roster_matrix = intvar(0, num_nurses - 1, shape=(shifts_per_day, num_days))

    # Define the constraints
    model = Model()

    # Constraint: Each shift in a day must be assigned to a different nurse
    for day in range(num_days):
        model += AllDifferent(roster_matrix[:, day])

    # Constraint: The last shift of a day cannot have the same nurse as the first shift of the next day
    for day in range(num_days - 1):
        model += (roster_matrix[shifts_per_day - 1, day] != roster_matrix[0, day + 1])
    
    # Make sure fair allocation of shifts
    min_nb_shifts = min([sum(roster_matrix == n) for n in range(num_nurses)])
    max_nb_shifts = max([sum(roster_matrix == n) for n in range(num_nurses)])
    model.minimize(max_nb_shifts - min_nb_shifts)
    
    return model, (roster_matrix,)

# %%
# Example data
num_nurses = 10
shifts_per_day = 5
num_days = 7

# %%
model, (roster,) = simple_nurse_rostering(num_nurses, shifts_per_day, num_days)

# %%
import pandas as pd

def weekday(i):
    if i % 7 == 0: return "Monday"
    if i % 7 == 1: return "Tuesday"
    if i % 7 == 2: return "Wednesday"
    if i % 7 == 3: return "Thursday"
    if i % 7 == 4: return "Friday"
    if i % 7 == 5: return "Saturday"
    if i % 7 == 6: return "Sunday"
    

def make_pretty_roster(styler):

    styler.set_caption("Nurse roster")
    styler.format_index(lambda v: f"Shift {v+1}")
    styler.format_index(weekday, axis="columns")
    styler.background_gradient(axis=None, vmin=1, vmax=num_nurses, cmap="Pastel1") 
    styler.set_properties(**{'text-align': 'center'})
    display(styler)

# %%
# Solve the problem
solution = model.solve()

if solution:
    # Display the nurse roster
    pd.DataFrame(roster.value()+1).style.pipe(make_pretty_roster)
else:
    print("No solution found.")
    print(model)
# Out:
# <style type="text/css">
# #T_b4cb4_row0_col0, #T_b4cb4_row2_col1, #T_b4cb4_row2_col2, #T_b4cb4_row2_col5 {
#   background-color: #e5d8bd;
#   color: #000000;
#   text-align: center;
# }
# #T_b4cb4_row0_col1, #T_b4cb4_row0_col5, #T_b4cb4_row2_col0, #T_b4cb4_row2_col3, #T_b4cb4_row3_col2, #T_b4cb4_row3_col4 {
#   background-color: #f2f2f2;
#   color: #000000;
#   text-align: center;
# }
# #T_b4cb4_row0_col2, #T_b4cb4_row0_col6, #T_b4cb4_row4_col3, #T_b4cb4_row4_col4 {
#   background-color: #b3cde3;
#   color: #000000;
#   text-align: center;
# }
# #T_b4cb4_row0_col3, #T_b4cb4_row1_col1, #T_b4cb4_row1_col5, #T_b4cb4_row3_col6 {
#   background-color: #decbe4;
#   color: #000000;
#   text-align: center;
# }
# #T_b4cb4_row0_col4, #T_b4cb4_row2_col6, #T_b4cb4_row3_col3, #T_b4cb4_row4_col0 {
#   background-color: #ccebc5;
#   color: #000000;
#   text-align: center;
# }
# #T_b4cb4_row1_col0, #T_b4cb4_row1_col4, #T_b4cb4_row4_col2 {
#   background-color: #ffffcc;
#   color: #000000;
#   text-align: center;
# }
# #T_b4cb4_row1_col2, #T_b4cb4_row1_col6, #T_b4cb4_row3_col0 {
#   background-color: #fed9a6;
#   color: #000000;
#   text-align: center;
# }
# #T_b4cb4_row1_col3, #T_b4cb4_row2_col4, #T_b4cb4_row3_col1, #T_b4cb4_row3_col5 {
#   background-color: #fbb4ae;
#   color: #000000;
#   text-align: center;
# }
# #T_b4cb4_row4_col1, #T_b4cb4_row4_col5, #T_b4cb4_row4_col6 {
#   background-color: #fddaec;
#   color: #000000;
#   text-align: center;
# }
# </style>
# <table id="T_b4cb4">
#   <caption>Nurse roster</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4cb4_level0_col0" class="col_heading level0 col0" >Monday</th>
#       <th id="T_b4cb4_level0_col1" class="col_heading level0 col1" >Tuesday</th>
#       <th id="T_b4cb4_level0_col2" class="col_heading level0 col2" >Wednesday</th>
#       <th id="T_b4cb4_level0_col3" class="col_heading level0 col3" >Thursday</th>
#       <th id="T_b4cb4_level0_col4" class="col_heading level0 col4" >Friday</th>
#       <th id="T_b4cb4_level0_col5" class="col_heading level0 col5" >Saturday</th>
#       <th id="T_b4cb4_level0_col6" class="col_heading level0 col6" >Sunday</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4cb4_level0_row0" class="row_heading level0 row0" >Shift 1</th>
#       <td id="T_b4cb4_row0_col0" class="data row0 col0" >7</td>
#       <td id="T_b4cb4_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_b4cb4_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_b4cb4_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_b4cb4_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_b4cb4_row0_col5" class="data row0 col5" >10</td>
#       <td id="T_b4cb4_row0_col6" class="data row0 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_b4cb4_level0_row1" class="row_heading level0 row1" >Shift 2</th>
#       <td id="T_b4cb4_row1_col0" class="data row1 col0" >6</td>
#       <td id="T_b4cb4_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_b4cb4_row1_col2" class="data row1 col2" >5</td>
#       <td id="T_b4cb4_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_b4cb4_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_b4cb4_row1_col5" class="data row1 col5" >4</td>
#       <td id="T_b4cb4_row1_col6" class="data row1 col6" >5</td>
#     </tr>
#     <tr>
#       <th id="T_b4cb4_level0_row2" class="row_heading level0 row2" >Shift 3</th>
#       <td id="T_b4cb4_row2_col0" class="data row2 col0" >9</td>
#       <td id="T_b4cb4_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_b4cb4_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_b4cb4_row2_col3" class="data row2 col3" >9</td>
#       <td id="T_b4cb4_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_b4cb4_row2_col5" class="data row2 col5" >7</td>
#       <td id="T_b4cb4_row2_col6" class="data row2 col6" >3</td>
#     </tr>
#     <tr>
#       <th id="T_b4cb4_level0_row3" class="row_heading level0 row3" >Shift 4</th>
#       <td id="T_b4cb4_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_b4cb4_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_b4cb4_row3_col2" class="data row3 col2" >10</td>
#       <td id="T_b4cb4_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_b4cb4_row3_col4" class="data row3 col4" >9</td>
#       <td id="T_b4cb4_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_b4cb4_row3_col6" class="data row3 col6" >4</td>
#     </tr>
#     <tr>
#       <th id="T_b4cb4_level0_row4" class="row_heading level0 row4" >Shift 5</th>
#       <td id="T_b4cb4_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_b4cb4_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_b4cb4_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_b4cb4_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_b4cb4_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_b4cb4_row4_col5" class="data row4 col5" >8</td>
#       <td id="T_b4cb4_row4_col6" class="data row4 col6" >8</td>
#     </tr>
#   </tbody>
# </table>
